# %% [markdown]
# 1. Import Packages

# %%
import pandas as pd
import numpy as np
import mysql.connector as db

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 2. Read a CSV file

# %%
df = pd.read_csv("seccheck_data.csv")
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# 0              19       Asian     Drunk Driving  Speeding              True
# 1              58       Other             Other     Other             False
# 2              76       Black  Signal Violation  Speeding             False
# 3              76       Black          Speeding       DUI              True
# 4              75       Other          Speeding     Other             False
# ...           ...         ...               ...       ...               ...
# 65533          48       Black             Other     Other             False
# 65534          35    Hispanic          Seatbelt     Other              True
# 65535          41       Asian          Seatbelt       DUI              True
# 65536          63       Black          Seatbelt     Other             False
# 65537          32       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536             NaN      Warning         True      0-15 Min
# 65537             NaN       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 16 columns]

# %% [markdown]
# 3. Data Cleaning

# %% [markdown]
# i) Drop unwanted columns

# %%
df.drop(["driver_age_raw","violation_raw"],axis = 1,inplace = True)

# %% [markdown]
# ii) Identify missing values

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age                0
# driver_race               0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
df['search_type'].unique()
# Out:
# array(['Vehicle Search', 'Frisk', nan], dtype=object)

# %%
srhtype= df['search_type'].mode()[0]
srhtype
# Out:
# 'Frisk'

# %%
df['search_type'].fillna(srhtype, inplace= True)

# %%
df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age            0
# driver_race           0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
data1 = df.head(500)
data1
# Out:
#       stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 0    2020-01-01   0:00:00       Canada             M          19       Asian
# 1    2020-01-01   0:01:00        India             M          58       Other
# 2    2020-01-01   0:02:00          USA             M          76       Black
# 3    2020-01-01   0:03:00       Canada             M          76       Black
# 4    2020-01-01   0:04:00       Canada             M          75       Other
# ..          ...       ...          ...           ...         ...         ...
# 495  2020-01-01   8:15:00          USA             M          67       Black
# 496  2020-01-01   8:16:00       Canada             M          75       Asian
# 497  2020-01-01   8:17:00          USA             M          75    Hispanic
# 498  2020-01-01   8:18:00       Canada             M          32    Hispanic
# 499  2020-01-01   8:19:00          USA             M          63       Other
#
#     violation  search_conducted     search_type stop_outcome  is_arrested  \
# 0    Speeding              True  Vehicle Search       Ticket         True
# 1       Other             False  Vehicle Search       Arrest         True
# 2    Speeding             False           Frisk       Ticket         True
# 3         DUI              True           Frisk      Warning        False
# 4       Other             False  Vehicle Search       Arrest         True
# ..        ...               ...             ...          ...          ...
# 495    Signal             False  Vehicle Search       Arrest        False
# 496     Other              True  Vehicle Search      Warning        False
# 497  Speeding              True           Frisk       Arrest        False
# 498     Other             False  Vehicle Search       Arrest        False
# 499    Signal             False           Frisk       Arrest         True
#
#     stop_duration  drugs_related_stop vehicle_number
# 0       16-30 Min                True     UP76DY3473
# 1       16-30 Min                True     RJ83PZ4441
# 2       16-30 Min                True     RJ32OM7264
# 3        0-15 Min                True     RJ76TI3807
# 4       16-30 Min               False     WB63BB8305
# ..            ...                 ...            ...
# 495      0-15 Min               False     DL37CK3012
# 496     16-30 Min                True     KA76OG9154
# 497       30+ Min               False     TN10OV8122
# 498       30+ Min               False     DL91QW3561
# 499       30+ Min                True     KA94DL5663
#
# [500 rows x 14 columns]

# %%
data1.dtypes
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age             int64
# driver_race           object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %% [markdown]
# 4. convert all rows into a list of tuples

# %%
value = data1.values
value
# Out:
# array([['2020-01-01', '0:00:00', 'Canada', ..., '16-30 Min', True,
#         'UP76DY3473'],
#        ['2020-01-01', '0:01:00', 'India', ..., '16-30 Min', True,
#         'RJ83PZ4441'],
#        ['2020-01-01', '0:02:00', 'USA', ..., '16-30 Min', True,
#         'RJ32OM7264'],
#        ...,
#        ['2020-01-01', '8:17:00', 'USA', ..., '30+ Min', False,
#         'TN10OV8122'],
#        ['2020-01-01', '8:18:00', 'Canada', ..., '30+ Min', False,
#         'DL91QW3561'],
#        ['2020-01-01', '8:19:00', 'USA', ..., '30+ Min', True,
#         'KA94DL5663']], dtype=object)

# %%
num_array = np.array(value)
val = list(map(tuple, num_array))

val
# Out:
# [('2020-01-01',
#   '0:00:00',
#   'Canada',
#   'M',
#   19,
#   'Asian',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'UP76DY3473'),
#  ('2020-01-01',
#   '0:01:00',
#   'India',
#   'M',
#   58,
#   'Other',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'RJ83PZ4441'),
#  ('2020-01-01',
#   '0:02:00',
#   'USA',
#   'M',
#   76,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'RJ32OM7264'),
#  ('2020-01-01',
#   '0:03:00',
#   'Canada',
#   'M',
#   76,
#   'Black',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'RJ76TI3807'),
#  ('2020-01-01',
#   '0:04:00',
#   'Canada',
#   'M',
#   75,
#   'Other',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB63BB8305'),
#  ('2020-01-01',
#   '0:05:00',
#   'Canada',
#   'F',
#   73,
#   'Other',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'MH89ZF7676'),
#  ('2020-01-01',
#   '0:06:00',
#   'USA',
#   'F',
#   70,
#   'White',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'KA40AD3153'),
#  ('2020-01-01',
#   '0:07:00',
#   'India',
#   'M',
#   50,
#   'Asian',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'DL75KZ7835'),
#  ('2020-01-01',
#   '0:08:00',
#   'USA',
#   'F',
#   30,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'DL50PO5101'),
#  ('2020-01-01',
#   '0:09:00',
#   'USA',
#   'M',
#   21,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'KA79RD2271'),
#  ('2020-01-01',
#   '0:10:00',
#   'India',
#   'F',
#   76,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'UP67CQ9426'),
#  ('2020-01-01',
#   '0:11:00',
#   'Canada',
#   'F',
#   53,
#   'Hispanic',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'KA61JB1004'),
#  ('2020-01-01',
#   '0:12:00',
#   'India',
#   'M',
#   46,
#   'Asian',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'WB70IV9884'),
#  ('2020-01-01',
#   '0:13:00',
#   'USA',
#   'M',
#   58,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'WB56XQ8946'),
#  ('2020-01-01',
#   '0:14:00',
#   'India',
#   'M',
#   25,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'GJ67CO6825'),
#  ('2020-01-01',
#   '0:15:00',
#   'USA',
#   'F',
#   51,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'WB75TF1052'),
#  ('2020-01-01',
#   '0:16:00',
#   'India',
#   'M',
#   21,
#   'Asian',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'UP82DB7554'),
#  ('2020-01-01',
#   '0:17:00',
#   'Canada',
#   'F',
#   55,
#   'White',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'MH15GS2782'),
#  ('2020-01-01',
#   '0:18:00',
#   'USA',
#   'M',
#   71,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'MH80WR1351'),
#  ('2020-01-01',
#   '0:19:00',
#   'Canada',
#   'F',
#   41,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'KA12GK6861'),
#  ('2020-01-01',
#   '0:20:00',
#   'USA',
#   'F',
#   47,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'KA78HN8680'),
#  ('2020-01-01',
#   '0:21:00',
#   'Canada',
#   'F',
#   25,
#   'Black',
#   'DUI',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'WB35BJ2947'),
#  ('2020-01-01',
#   '0:22:00',
#   'USA',
#   'F',
#   59,
#   'Asian',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'GJ46IJ2247'),
#  ('2020-01-01',
#   '0:23:00',
#   'Canada',
#   'F',
#   60,
#   'Black',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'GJ24GN5905'),
#  ('2020-01-01',
#   '0:24:00',
#   'India',
#   'M',
#   76,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'MH83XS7688'),
#  ('2020-01-01',
#   '0:25:00',
#   'USA',
#   'F',
#   58,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'KA95EW9912'),
#  ('2020-01-01',
#   '0:26:00',
#   'Canada',
#   'F',
#   56,
#   'Asian',
#   'Other',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'DL36PY9336'),
#  ('2020-01-01',
#   '0:27:00',
#   'India',
#   'F',
#   61,
#   'Other',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'MH17TG9873'),
#  ('2020-01-01',
#   '0:28:00',
#   'USA',
#   'F',
#   69,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'GJ67TR1208'),
#  ('2020-01-01',
#   '0:29:00',
#   'USA',
#   'M',
#   39,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'RJ65DM5842'),
#  ('2020-01-01',
#   '0:30:00',
#   'USA',
#   'M',
#   23,
#   'Other',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'RJ71DT4429'),
#  ('2020-01-01',
#   '0:31:00',
#   'USA',
#   'F',
#   73,
#   'Asian',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'WB45XD7874'),
#  ('2020-01-01',
#   '0:32:00',
#   'India',
#   'F',
#   26,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'GJ29NI1072'),
#  ('2020-01-01',
#   '0:33:00',
#   'India',
#   'M',
#   70,
#   'Other',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'DL50DZ6634'),
#  ('2020-01-01',
#   '0:34:00',
#   'Canada',
#   'M',
#   46,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'GJ18QH1179'),
#  ('2020-01-01',
#   '0:35:00',
#   'USA',
#   'M',
#   24,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'DL92KH6072'),
#  ('2020-01-01',
#   '0:36:00',
#   'Canada',
#   'F',
#   46,
#   'Other',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'DL97PL3910'),
#  ('2020-01-01',
#   '0:37:00',
#   'Canada',
#   'F',
#   64,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'DL78IQ3578'),
#  ('2020-01-01',
#   '0:38:00',
#   'Canada',
#   'F',
#   76,
#   'Hispanic',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'RJ86OH2697'),
#  ('2020-01-01',
#   '0:39:00',
#   'USA',
#   'F',
#   68,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'GJ17ED4625'),
#  ('2020-01-01',
#   '0:40:00',
#   'India',
#   'M',
#   65,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'GJ34GW6344'),
#  ('2020-01-01',
#   '0:41:00',
#   'Canada',
#   'M',
#   67,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ83AS9833'),
#  ('2020-01-01',
#   '0:42:00',
#   'USA',
#   'M',
#   71,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'GJ62CZ2524'),
#  ('2020-01-01',
#   '0:43:00',
#   'USA',
#   'M',
#   74,
#   'White',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'TN43VS9229'),
#  ('2020-01-01',
#   '0:44:00',
#   'India',
#   'F',
#   61,
#   'Other',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'MH88XZ1430'),
#  ('2020-01-01',
#   '0:45:00',
#   'India',
#   'F',
#   64,
#   'Asian',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'DL31KD2035'),
#  ('2020-01-01',
#   '0:46:00',
#   'India',
#   'M',
#   32,
#   'Hispanic',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'TN84HR9877'),
#  ('2020-01-01',
#   '0:47:00',
#   'Canada',
#   'M',
#   23,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'DL82AO6838'),
#  ('2020-01-01',
#   '0:48:00',
#   'USA',
#   'M',
#   28,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'MH41QW2497'),
#  ('2020-01-01',
#   '0:49:00',
#   'Canada',
#   'F',
#   47,
#   'White',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'DL13ZS8904'),
#  ('2020-01-01',
#   '0:50:00',
#   'Canada',
#   'F',
#   18,
#   'White',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'MH37EG9241'),
#  ('2020-01-01',
#   '0:51:00',
#   'India',
#   'F',
#   76,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'KA50EI7957'),
#  ('2020-01-01',
#   '0:52:00',
#   'USA',
#   'F',
#   61,
#   'White',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'KA64GY4451'),
#  ('2020-01-01',
#   '0:53:00',
#   'Canada',
#   'F',
#   43,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ17GE2142'),
#  ('2020-01-01',
#   '0:54:00',
#   'USA',
#   'M',
#   32,
#   'White',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'KA73KN5444'),
#  ('2020-01-01',
#   '0:55:00',
#   'India',
#   'M',
#   32,
#   'Asian',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'MH58AO2763'),
#  ('2020-01-01',
#   '0:56:00',
#   'USA',
#   'F',
#   68,
#   'White',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'DL85LD9268'),
#  ('2020-01-01',
#   '0:57:00',
#   'Canada',
#   'F',
#   25,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'GJ72CL4694'),
#  ('2020-01-01',
#   '0:58:00',
#   'USA',
#   'M',
#   48,
#   'Hispanic',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'RJ66EL4572'),
#  ('2020-01-01',
#   '0:59:00',
#   'India',
#   'M',
#   30,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'WB71MG2848'),
#  ('2020-01-01',
#   '1:00:00',
#   'Canada',
#   'M',
#   76,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'MH16SA1781'),
#  ('2020-01-01',
#   '1:01:00',
#   'USA',
#   'F',
#   28,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'DL48XQ7468'),
#  ('2020-01-01',
#   '1:02:00',
#   'India',
#   'M',
#   60,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'MH47UP7891'),
#  ('2020-01-01',
#   '1:03:00',
#   'India',
#   'F',
#   78,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'KA25VM7960'),
#  ('2020-01-01',
#   '1:04:00',
#   'Canada',
#   'M',
#   51,
#   'White',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'DL10UB3062'),
#  ('2020-01-01',
#   '1:05:00',
#   'USA',
#   'F',
#   77,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'RJ36PA3655'),
#  ('2020-01-01',
#   '1:06:00',
#   'Canada',
#   'F',
#   71,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'GJ41BV7342'),
#  ('2020-01-01',
#   '1:07:00',
#   'Canada',
#   'M',
#   22,
#   'Asian',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'GJ11LO3819'),
#  ('2020-01-01',
#   '1:08:00',
#   'Canada',
#   'F',
#   31,
#   'Other',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'WB34ID1259'),
#  ('2020-01-01',
#   '1:09:00',
#   'USA',
#   'F',
#   68,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'GJ50WS8237'),
#  ('2020-01-01',
#   '1:10:00',
#   'India',
#   'M',
#   60,
#   'Asian',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'DL81FJ4363'),
#  ('2020-01-01',
#   '1:11:00',
#   'India',
#   'M',
#   32,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'GJ88KF5573'),
#  ('2020-01-01',
#   '1:12:00',
#   'USA',
#   'M',
#   37,
#   'Black',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'RJ40ZT3886'),
#  ('2020-01-01',
#   '1:13:00',
#   'India',
#   'F',
#   74,
#   'Other',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'MH65RK4033'),
#  ('2020-01-01',
#   '1:14:00',
#   'USA',
#   'F',
#   24,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'UP53KC7731'),
#  ('2020-01-01',
#   '1:15:00',
#   'USA',
#   'M',
#   55,
#   'White',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'MH28UO7873'),
#  ('2020-01-01',
#   '1:16:00',
#   'India',
#   'M',
#   35,
#   'Black',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'TN50GM4181'),
#  ('2020-01-01',
#   '1:17:00',
#   'India',
#   'F',
#   75,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'GJ84VR4769'),
#  ('2020-01-01',
#   '1:18:00',
#   'USA',
#   'M',
#   39,
#   'Other',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'UP57UB2650'),
#  ('2020-01-01',
#   '1:19:00',
#   'USA',
#   'M',
#   26,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'UP65SH6528'),
#  ('2020-01-01',
#   '1:20:00',
#   'USA',
#   'F',
#   21,
#   'Asian',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'WB99ER1139'),
#  ('2020-01-01',
#   '1:21:00',
#   'Canada',
#   'M',
#   40,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'RJ35JA3159'),
#  ('2020-01-01',
#   '1:22:00',
#   'USA',
#   'M',
#   53,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'KA92WF8533'),
#  ('2020-01-01',
#   '1:23:00',
#   'USA',
#   'F',
#   21,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'TN94SX3537'),
#  ('2020-01-01',
#   '1:24:00',
#   'USA',
#   'M',
#   22,
#   'Black',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'DL36CV6003'),
#  ('2020-01-01',
#   '1:25:00',
#   'USA',
#   'M',
#   50,
#   'Other',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'DL90XB1655'),
#  ('2020-01-01',
#   '1:26:00',
#   'USA',
#   'M',
#   55,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'GJ90BL5009'),
#  ('2020-01-01',
#   '1:27:00',
#   'India',
#   'F',
#   20,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'WB19UQ8951'),
#  ('2020-01-01',
#   '1:28:00',
#   'Canada',
#   'M',
#   19,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'WB96XV1244'),
#  ('2020-01-01',
#   '1:29:00',
#   'USA',
#   'F',
#   64,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'TN87GU9888'),
#  ('2020-01-01',
#   '1:30:00',
#   'India',
#   'F',
#   63,
#   'Asian',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'MH82TP6195'),
#  ('2020-01-01',
#   '1:31:00',
#   'India',
#   'F',
#   49,
#   'Other',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ36QW4221'),
#  ('2020-01-01',
#   '1:32:00',
#   'USA',
#   'F',
#   35,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'WB88YO8532'),
#  ('2020-01-01',
#   '1:33:00',
#   'USA',
#   'F',
#   75,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'RJ45XR5576'),
#  ('2020-01-01',
#   '1:34:00',
#   'India',
#   'M',
#   39,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'RJ91YV2437'),
#  ('2020-01-01',
#   '1:35:00',
#   'USA',
#   'M',
#   64,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'RJ93ID8505'),
#  ('2020-01-01',
#   '1:36:00',
#   'USA',
#   'M',
#   47,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'UP77ON6789'),
#  ('2020-01-01',
#   '1:37:00',
#   'USA',
#   'M',
#   41,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'WB90WK6774'),
#  ('2020-01-01',
#   '1:38:00',
#   'India',
#   'F',
#   65,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'KA14JB4215'),
#  ('2020-01-01',
#   '1:39:00',
#   'USA',
#   'F',
#   48,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'UP69PU2954'),
#  ('2020-01-01',
#   '1:40:00',
#   'India',
#   'F',
#   26,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'UP98QY4152'),
#  ('2020-01-01',
#   '1:41:00',
#   'Canada',
#   'M',
#   59,
#   'White',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'UP63BA2421'),
#  ('2020-01-01',
#   '1:42:00',
#   'India',
#   'M',
#   63,
#   'Asian',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'DL66AF3486'),
#  ('2020-01-01',
#   '1:43:00',
#   'USA',
#   'M',
#   39,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'RJ49WE2709'),
#  ('2020-01-01',
#   '1:44:00',
#   'USA',
#   'F',
#   32,
#   'Asian',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'GJ22LE3279'),
#  ('2020-01-01',
#   '1:45:00',
#   'India',
#   'F',
#   48,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'TN36WR9825'),
#  ('2020-01-01',
#   '1:46:00',
#   'Canada',
#   'F',
#   37,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'RJ91XQ7488'),
#  ('2020-01-01',
#   '1:47:00',
#   'Canada',
#   'F',
#   69,
#   'Black',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'DL31LO7439'),
#  ('2020-01-01',
#   '1:48:00',
#   'India',
#   'F',
#   25,
#   'Other',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'TN73HG4068'),
#  ('2020-01-01',
#   '1:49:00',
#   'USA',
#   'F',
#   71,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'UP75GK5444'),
#  ('2020-01-01',
#   '1:50:00',
#   'Canada',
#   'F',
#   45,
#   'Hispanic',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'UP23YN8383'),
#  ('2020-01-01',
#   '1:51:00',
#   'USA',
#   'F',
#   24,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'UP57IX8805'),
#  ('2020-01-01',
#   '1:52:00',
#   'USA',
#   'M',
#   63,
#   'White',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'MH10WH5889'),
#  ('2020-01-01',
#   '1:53:00',
#   'Canada',
#   'F',
#   70,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'DL28SV9081'),
#  ('2020-01-01',
#   '1:54:00',
#   'Canada',
#   'F',
#   61,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'UP22IQ4731'),
#  ('2020-01-01',
#   '1:55:00',
#   'Canada',
#   'M',
#   38,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'TN88OZ3477'),
#  ('2020-01-01',
#   '1:56:00',
#   'USA',
#   'M',
#   68,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'MH87SR5399'),
#  ('2020-01-01',
#   '1:57:00',
#   'USA',
#   'F',
#   46,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'RJ39WM9690'),
#  ('2020-01-01',
#   '1:58:00',
#   'India',
#   'M',
#   22,
#   'Black',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'TN16TE5832'),
#  ('2020-01-01',
#   '1:59:00',
#   'India',
#   'M',
#   48,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'RJ50JG3850'),
#  ('2020-01-01',
#   '2:00:00',
#   'USA',
#   'M',
#   18,
#   'Black',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'TN75VL3241'),
#  ('2020-01-01',
#   '2:01:00',
#   'Canada',
#   'F',
#   21,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'DL45TE2262'),
#  ('2020-01-01',
#   '2:02:00',
#   'India',
#   'F',
#   56,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB24MZ8320'),
#  ('2020-01-01',
#   '2:03:00',
#   'India',
#   'F',
#   22,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'GJ31OC3613'),
#  ('2020-01-01',
#   '2:04:00',
#   'Canada',
#   'F',
#   72,
#   'White',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'RJ80OM6655'),
#  ('2020-01-01',
#   '2:05:00',
#   'USA',
#   'F',
#   50,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'MH55DL5389'),
#  ('2020-01-01',
#   '2:06:00',
#   'Canada',
#   'M',
#   43,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'WB64WR4825'),
#  ('2020-01-01',
#   '2:07:00',
#   'USA',
#   'F',
#   58,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'GJ48WU6439'),
#  ('2020-01-01',
#   '2:08:00',
#   'India',
#   'F',
#   79,
#   'Other',
#   'Other',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'DL87BX7671'),
#  ('2020-01-01',
#   '2:09:00',
#   'Canada',
#   'M',
#   79,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'DL18KE5706'),
#  ('2020-01-01',
#   '2:10:00',
#   'India',
#   'M',
#   67,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'MH29JU7418'),
#  ('2020-01-01',
#   '2:11:00',
#   'India',
#   'M',
#   74,
#   'Asian',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'MH60WX8852'),
#  ('2020-01-01',
#   '2:12:00',
#   'Canada',
#   'M',
#   47,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'DL69ON5971'),
#  ('2020-01-01',
#   '2:13:00',
#   'India',
#   'M',
#   36,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'DL85HV3400'),
#  ('2020-01-01',
#   '2:14:00',
#   'India',
#   'F',
#   79,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'DL84SY8912'),
#  ('2020-01-01',
#   '2:15:00',
#   'India',
#   'F',
#   53,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'UP20GI1142'),
#  ('2020-01-01',
#   '2:16:00',
#   'USA',
#   'M',
#   66,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'TN90PN2999'),
#  ('2020-01-01',
#   '2:17:00',
#   'Canada',
#   'F',
#   80,
#   'Black',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'DL32WR7792'),
#  ('2020-01-01',
#   '2:18:00',
#   'India',
#   'M',
#   63,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'RJ81PF4808'),
#  ('2020-01-01',
#   '2:19:00',
#   'USA',
#   'M',
#   64,
#   'White',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ23DR9743'),
#  ('2020-01-01',
#   '2:20:00',
#   'Canada',
#   'F',
#   69,
#   'White',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'RJ80ML8681'),
#  ('2020-01-01',
#   '2:21:00',
#   'Canada',
#   'M',
#   43,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'UP51LZ2597'),
#  ('2020-01-01',
#   '2:22:00',
#   'Canada',
#   'M',
#   32,
#   'Hispanic',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'MH52YO1565'),
#  ('2020-01-01',
#   '2:23:00',
#   'Canada',
#   'M',
#   40,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'UP70XC3264'),
#  ('2020-01-01',
#   '2:24:00',
#   'USA',
#   'F',
#   22,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'MH57SO9110'),
#  ('2020-01-01',
#   '2:25:00',
#   'India',
#   'F',
#   69,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'RJ41IF3630'),
#  ('2020-01-01',
#   '2:26:00',
#   'Canada',
#   'F',
#   70,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'UP74NZ6165'),
#  ('2020-01-01',
#   '2:27:00',
#   'India',
#   'F',
#   76,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'WB39NV9620'),
#  ('2020-01-01',
#   '2:28:00',
#   'India',
#   'F',
#   44,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'MH28MG8771'),
#  ('2020-01-01',
#   '2:29:00',
#   'USA',
#   'F',
#   67,
#   'White',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'TN90WP3979'),
#  ('2020-01-01',
#   '2:30:00',
#   'USA',
#   'F',
#   67,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'RJ51TI4397'),
#  ('2020-01-01',
#   '2:31:00',
#   'USA',
#   'F',
#   60,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'RJ64RL5151'),
#  ('2020-01-01',
#   '2:32:00',
#   'India',
#   'M',
#   80,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ58AZ4857'),
#  ('2020-01-01',
#   '2:33:00',
#   'India',
#   'M',
#   79,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'GJ13OM4004'),
#  ('2020-01-01',
#   '2:34:00',
#   'Canada',
#   'F',
#   38,
#   'Other',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'MH98JV5594'),
#  ('2020-01-01',
#   '2:35:00',
#   'USA',
#   'F',
#   44,
#   'Asian',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'KA28JK9136'),
#  ('2020-01-01',
#   '2:36:00',
#   'India',
#   'F',
#   80,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'MH39RB8864'),
#  ('2020-01-01',
#   '2:37:00',
#   'USA',
#   'M',
#   54,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB90MN1350'),
#  ('2020-01-01',
#   '2:38:00',
#   'India',
#   'M',
#   49,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'DL10SD7037'),
#  ('2020-01-01',
#   '2:39:00',
#   'Canada',
#   'F',
#   53,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'WB20OZ5713'),
#  ('2020-01-01',
#   '2:40:00',
#   'Canada',
#   'M',
#   25,
#   'Asian',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ46RC6990'),
#  ('2020-01-01',
#   '2:41:00',
#   'Canada',
#   'F',
#   40,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'UP60ZM3897'),
#  ('2020-01-01',
#   '2:42:00',
#   'Canada',
#   'M',
#   76,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'MH66UK1367'),
#  ('2020-01-01',
#   '2:43:00',
#   'USA',
#   'F',
#   34,
#   'Hispanic',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'RJ74MI6996'),
#  ('2020-01-01',
#   '2:44:00',
#   'Canada',
#   'F',
#   69,
#   'Asian',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'RJ99WT2168'),
#  ('2020-01-01',
#   '2:45:00',
#   'Canada',
#   'M',
#   46,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'DL77PV2647'),
#  ('2020-01-01',
#   '2:46:00',
#   'USA',
#   'F',
#   55,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'UP42ZR7328'),
#  ('2020-01-01',
#   '2:47:00',
#   'Canada',
#   'M',
#   69,
#   'Other',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'KA31EW3735'),
#  ('2020-01-01',
#   '2:48:00',
#   'USA',
#   'M',
#   21,
#   'Asian',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'KA21NM4066'),
#  ('2020-01-01',
#   '2:49:00',
#   'India',
#   'M',
#   51,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'RJ14GS9371'),
#  ('2020-01-01',
#   '2:50:00',
#   'USA',
#   'M',
#   47,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'UP64SP1478'),
#  ('2020-01-01',
#   '2:51:00',
#   'USA',
#   'F',
#   66,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'RJ23AQ7762'),
#  ('2020-01-01',
#   '2:52:00',
#   'India',
#   'F',
#   29,
#   'Black',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'MH67EH9811'),
#  ('2020-01-01',
#   '2:53:00',
#   'Canada',
#   'F',
#   30,
#   'White',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'WB90TM7810'),
#  ('2020-01-01',
#   '2:54:00',
#   'USA',
#   'M',
#   59,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'GJ37SX3251'),
#  ('2020-01-01',
#   '2:55:00',
#   'India',
#   'M',
#   33,
#   'Black',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'WB65CR4049'),
#  ('2020-01-01',
#   '2:56:00',
#   'USA',
#   'F',
#   56,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'WB60AD3081'),
#  ('2020-01-01',
#   '2:57:00',
#   'India',
#   'F',
#   68,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'GJ46OY2005'),
#  ('2020-01-01',
#   '2:58:00',
#   'India',
#   'M',
#   21,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'UP73GI4591'),
#  ('2020-01-01',
#   '2:59:00',
#   'India',
#   'F',
#   63,
#   'Hispanic',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'KA23WS8090'),
#  ('2020-01-01',
#   '3:00:00',
#   'Canada',
#   'F',
#   25,
#   'White',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'DL61GF6932'),
#  ('2020-01-01',
#   '3:01:00',
#   'USA',
#   'F',
#   46,
#   'Other',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'UP96IG1615'),
#  ('2020-01-01',
#   '3:02:00',
#   'USA',
#   'M',
#   33,
#   'Hispanic',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'KA46AE8526'),
#  ('2020-01-01',
#   '3:03:00',
#   'India',
#   'F',
#   21,
#   'Other',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'RJ98PR9249'),
#  ('2020-01-01',
#   '3:04:00',
#   'USA',
#   'F',
#   26,
#   'Black',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'TN53LH4633'),
#  ('2020-01-01',
#   '3:05:00',
#   'India',
#   'M',
#   26,
#   'Asian',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'WB67XW6203'),
#  ('2020-01-01',
#   '3:06:00',
#   'USA',
#   'M',
#   67,
#   'Asian',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'RJ13AK2962'),
#  ('2020-01-01',
#   '3:07:00',
#   'India',
#   'M',
#   37,
#   'White',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'MH40VK2914'),
#  ('2020-01-01',
#   '3:08:00',
#   'Canada',
#   'F',
#   68,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'GJ12OV1732'),
#  ('2020-01-01',
#   '3:09:00',
#   'India',
#   'M',
#   62,
#   'Black',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'KA75PX6384'),
#  ('2020-01-01',
#   '3:10:00',
#   'Canada',
#   'M',
#   24,
#   'Hispanic',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'MH75WG4234'),
#  ('2020-01-01',
#   '3:11:00',
#   'USA',
#   'F',
#   46,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'WB87BM4877'),
#  ('2020-01-01',
#   '3:12:00',
#   'Canada',
#   'M',
#   27,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'MH94EZ7397'),
#  ('2020-01-01',
#   '3:13:00',
#   'USA',
#   'M',
#   36,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'UP95MS1428'),
#  ('2020-01-01',
#   '3:14:00',
#   'India',
#   'M',
#   78,
#   'Other',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'MH23CO2824'),
#  ('2020-01-01',
#   '3:15:00',
#   'India',
#   'F',
#   73,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'KA88AL9836'),
#  ('2020-01-01',
#   '3:16:00',
#   'India',
#   'M',
#   47,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'DL59KH9314'),
#  ('2020-01-01',
#   '3:17:00',
#   'India',
#   'M',
#   70,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'KA49IW6267'),
#  ('2020-01-01',
#   '3:18:00',
#   'Canada',
#   'F',
#   38,
#   'Other',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'WB56OW6709'),
#  ('2020-01-01',
#   '3:19:00',
#   'Canada',
#   'F',
#   74,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'DL94EB8969'),
#  ('2020-01-01',
#   '3:20:00',
#   'USA',
#   'F',
#   75,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'DL45KT1258'),
#  ('2020-01-01',
#   '3:21:00',
#   'Canada',
#   'F',
#   23,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'DL29TX8930'),
#  ('2020-01-01',
#   '3:22:00',
#   'Canada',
#   'M',
#   19,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'KA83EL3328'),
#  ('2020-01-01',
#   '3:23:00',
#   'USA',
#   'M',
#   69,
#   'Black',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'RJ38DZ6444'),
#  ('2020-01-01',
#   '3:24:00',
#   'India',
#   'M',
#   18,
#   'Black',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'RJ89JM1899'),
#  ('2020-01-01',
#   '3:25:00',
#   'Canada',
#   'M',
#   27,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'GJ83EQ8230'),
#  ('2020-01-01',
#   '3:26:00',
#   'USA',
#   'F',
#   50,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'UP38HK1712'),
#  ('2020-01-01',
#   '3:27:00',
#   'India',
#   'F',
#   67,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'MH98TS9474'),
#  ('2020-01-01',
#   '3:28:00',
#   'USA',
#   'F',
#   55,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'MH19TX7252'),
#  ('2020-01-01',
#   '3:29:00',
#   'Canada',
#   'M',
#   73,
#   'Other',
#   'DUI',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'MH58EN5934'),
#  ('2020-01-01',
#   '3:30:00',
#   'Canada',
#   'M',
#   56,
#   'Hispanic',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'TN40GN1546'),
#  ('2020-01-01',
#   '3:31:00',
#   'USA',
#   'M',
#   20,
#   'Black',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'GJ97ZG2462'),
#  ('2020-01-01',
#   '3:32:00',
#   'Canada',
#   'M',
#   72,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'UP23IJ6278'),
#  ('2020-01-01',
#   '3:33:00',
#   'Canada',
#   'M',
#   61,
#   'Hispanic',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'WB35RU1995'),
#  ('2020-01-01',
#   '3:34:00',
#   'Canada',
#   'F',
#   60,
#   'Other',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'TN19LS5610'),
#  ('2020-01-01',
#   '3:35:00',
#   'India',
#   'F',
#   28,
#   'Hispanic',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'TN14JO6643'),
#  ('2020-01-01',
#   '3:36:00',
#   'USA',
#   'F',
#   20,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'KA96HX2588'),
#  ('2020-01-01',
#   '3:37:00',
#   'India',
#   'M',
#   30,
#   'Other',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'UP86LP5027'),
#  ('2020-01-01',
#   '3:38:00',
#   'USA',
#   'F',
#   60,
#   'Other',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'TN93EJ9801'),
#  ('2020-01-01',
#   '3:39:00',
#   'Canada',
#   'F',
#   65,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'DL85ST1964'),
#  ('2020-01-01',
#   '3:40:00',
#   'India',
#   'M',
#   48,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'DL44KB7294'),
#  ('2020-01-01',
#   '3:41:00',
#   'India',
#   'F',
#   39,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'WB55EX9991'),
#  ('2020-01-01',
#   '3:42:00',
#   'Canada',
#   'M',
#   73,
#   'Other',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'KA71AI5080'),
#  ('2020-01-01',
#   '3:43:00',
#   'Canada',
#   'F',
#   70,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'WB66NN1675'),
#  ('2020-01-01',
#   '3:44:00',
#   'USA',
#   'M',
#   46,
#   'Asian',
#   'Speeding',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'GJ13BL1614'),
#  ('2020-01-01',
#   '3:45:00',
#   'USA',
#   'F',
#   80,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'KA43RO5367'),
#  ('2020-01-01',
#   '3:46:00',
#   'USA',
#   'M',
#   66,
#   'Other',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'KA99FD5112'),
#  ('2020-01-01',
#   '3:47:00',
#   'Canada',
#   'M',
#   25,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'KA36PV1535'),
#  ('2020-01-01',
#   '3:48:00',
#   'India',
#   'F',
#   54,
#   'Hispanic',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'WB34LT9632'),
#  ('2020-01-01',
#   '3:49:00',
#   'USA',
#   'M',
#   28,
#   'Hispanic',
#   'DUI',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'UP74PH1313'),
#  ('2020-01-01',
#   '3:50:00',
#   'Canada',
#   'F',
#   28,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'UP37TK9974'),
#  ('2020-01-01',
#   '3:51:00',
#   'USA',
#   'F',
#   49,
#   'Asian',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'MH14DN5198'),
#  ('2020-01-01',
#   '3:52:00',
#   'Canada',
#   'M',
#   75,
#   'Other',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'UP47GN1642'),
#  ('2020-01-01',
#   '3:53:00',
#   'India',
#   'M',
#   32,
#   'White',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'MH94LA2232'),
#  ('2020-01-01',
#   '3:54:00',
#   'India',
#   'F',
#   31,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'KA58DA6126'),
#  ('2020-01-01',
#   '3:55:00',
#   'Canada',
#   'M',
#   24,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'DL97FL6698'),
#  ('2020-01-01',
#   '3:56:00',
#   'USA',
#   'F',
#   29,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'WB41SB3576'),
#  ('2020-01-01',
#   '3:57:00',
#   'Canada',
#   'F',
#   60,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'TN99NM4840'),
#  ('2020-01-01',
#   '3:58:00',
#   'Canada',
#   'M',
#   76,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'DL22HG9859'),
#  ('2020-01-01',
#   '3:59:00',
#   'USA',
#   'F',
#   40,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'GJ85GT7600'),
#  ('2020-01-01',
#   '4:00:00',
#   'Canada',
#   'F',
#   41,
#   'Other',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'TN86AR4726'),
#  ('2020-01-01',
#   '4:01:00',
#   'India',
#   'M',
#   43,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'RJ37QS4808'),
#  ('2020-01-01',
#   '4:02:00',
#   'India',
#   'F',
#   70,
#   'White',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'KA28QC5221'),
#  ('2020-01-01',
#   '4:03:00',
#   'Canada',
#   'M',
#   35,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'WB13OL8688'),
#  ('2020-01-01',
#   '4:04:00',
#   'USA',
#   'M',
#   45,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'DL84GM8616'),
#  ('2020-01-01',
#   '4:05:00',
#   'India',
#   'M',
#   80,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'WB62DR6062'),
#  ('2020-01-01',
#   '4:06:00',
#   'Canada',
#   'M',
#   28,
#   'Hispanic',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'TN67XP3354'),
#  ('2020-01-01',
#   '4:07:00',
#   'Canada',
#   'M',
#   27,
#   'White',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'KA57GR1125'),
#  ('2020-01-01',
#   '4:08:00',
#   'USA',
#   'F',
#   78,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'MH45VP3657'),
#  ('2020-01-01',
#   '4:09:00',
#   'Canada',
#   'M',
#   72,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'WB79LI5330'),
#  ('2020-01-01',
#   '4:10:00',
#   'Canada',
#   'F',
#   47,
#   'White',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'WB16HT7692'),
#  ('2020-01-01',
#   '4:11:00',
#   'India',
#   'M',
#   29,
#   'White',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'WB49DO8287'),
#  ('2020-01-01',
#   '4:12:00',
#   'Canada',
#   'F',
#   34,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'DL96UF9389'),
#  ('2020-01-01',
#   '4:13:00',
#   'Canada',
#   'F',
#   77,
#   'White',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'MH25IC2782'),
#  ('2020-01-01',
#   '4:14:00',
#   'India',
#   'F',
#   20,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'WB82MJ6171'),
#  ('2020-01-01',
#   '4:15:00',
#   'USA',
#   'M',
#   70,
#   'Other',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'DL72GU8258'),
#  ('2020-01-01',
#   '4:16:00',
#   'USA',
#   'M',
#   59,
#   'Asian',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'UP49YS1166'),
#  ('2020-01-01',
#   '4:17:00',
#   'India',
#   'F',
#   26,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'TN93OD1532'),
#  ('2020-01-01',
#   '4:18:00',
#   'India',
#   'F',
#   68,
#   'Black',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'GJ28EG1888'),
#  ('2020-01-01',
#   '4:19:00',
#   'Canada',
#   'M',
#   53,
#   'Black',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'KA60SI3876'),
#  ('2020-01-01',
#   '4:20:00',
#   'Canada',
#   'F',
#   43,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'UP43NB3095'),
#  ('2020-01-01',
#   '4:21:00',
#   'India',
#   'F',
#   47,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'MH38TR4631'),
#  ('2020-01-01',
#   '4:22:00',
#   'Canada',
#   'F',
#   23,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'GJ72ZP7972'),
#  ('2020-01-01',
#   '4:23:00',
#   'Canada',
#   'F',
#   56,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'DL37PA6936'),
#  ('2020-01-01',
#   '4:24:00',
#   'Canada',
#   'M',
#   42,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'UP17IB7858'),
#  ('2020-01-01',
#   '4:25:00',
#   'India',
#   'F',
#   59,
#   'White',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'DL65NT6558'),
#  ('2020-01-01',
#   '4:26:00',
#   'USA',
#   'F',
#   22,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'TN65FL1277'),
#  ('2020-01-01',
#   '4:27:00',
#   'India',
#   'M',
#   27,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'WB87EX7190'),
#  ('2020-01-01',
#   '4:28:00',
#   'USA',
#   'F',
#   61,
#   'White',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'MH38XN5395'),
#  ('2020-01-01',
#   '4:29:00',
#   'USA',
#   'M',
#   41,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ61ST9539'),
#  ('2020-01-01',
#   '4:30:00',
#   'India',
#   'F',
#   31,
#   'Other',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   True,
#   'MH44HQ9555'),
#  ('2020-01-01',
#   '4:31:00',
#   'USA',
#   'M',
#   75,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB52ZL9214'),
#  ('2020-01-01',
#   '4:32:00',
#   'Canada',
#   'M',
#   53,
#   'Asian',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'WB62MN8164'),
#  ('2020-01-01',
#   '4:33:00',
#   'India',
#   'F',
#   77,
#   'White',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'RJ51BO9704'),
#  ('2020-01-01',
#   '4:34:00',
#   'USA',
#   'F',
#   23,
#   'Asian',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'TN91QY3901'),
#  ('2020-01-01',
#   '4:35:00',
#   'India',
#   'M',
#   52,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'WB79DJ1324'),
#  ('2020-01-01',
#   '4:36:00',
#   'Canada',
#   'M',
#   77,
#   'Black',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   False,
#   'TN53CZ7203'),
#  ('2020-01-01',
#   '4:37:00',
#   'USA',
#   'F',
#   52,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'MH44PT6349'),
#  ('2020-01-01',
#   '4:38:00',
#   'USA',
#   'M',
#   65,
#   'Black',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'DL98VY4919'),
#  ('2020-01-01',
#   '4:39:00',
#   'India',
#   'F',
#   27,
#   'Other',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'DL78JZ4639'),
#  ('2020-01-01',
#   '4:40:00',
#   'Canada',
#   'F',
#   78,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'TN66RP4558'),
#  ('2020-01-01',
#   '4:41:00',
#   'India',
#   'M',
#   27,
#   'Black',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'DL97RO8146'),
#  ('2020-01-01',
#   '4:42:00',
#   'India',
#   'M',
#   38,
#   'White',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'TN48XS2683'),
#  ('2020-01-01',
#   '4:43:00',
#   'Canada',
#   'M',
#   62,
#   'Asian',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'UP57YP8070'),
#  ('2020-01-01',
#   '4:44:00',
#   'Canada',
#   'F',
#   63,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ67OD6049'),
#  ('2020-01-01',
#   '4:45:00',
#   'USA',
#   'M',
#   22,
#   'Other',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'WB20ZZ8884'),
#  ('2020-01-01',
#   '4:46:00',
#   'Canada',
#   'F',
#   45,
#   'Black',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'KA28SK2938'),
#  ('2020-01-01',
#   '4:47:00',
#   'India',
#   'F',
#   63,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'TN27KY7663'),
#  ('2020-01-01',
#   '4:48:00',
#   'USA',
#   'M',
#   39,
#   'Other',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'RJ72MO9356'),
#  ('2020-01-01',
#   '4:49:00',
#   'India',
#   'F',
#   75,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'GJ97RX3874'),
#  ('2020-01-01',
#   '4:50:00',
#   'Canada',
#   'F',
#   44,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'GJ30ZH8011'),
#  ('2020-01-01',
#   '4:51:00',
#   'Canada',
#   'M',
#   67,
#   'White',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   False,
#   'GJ64ES6938'),
#  ('2020-01-01',
#   '4:52:00',
#   'USA',
#   'F',
#   64,
#   'Other',
#   'DUI',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'UP47JU8417'),
#  ('2020-01-01',
#   '4:53:00',
#   'USA',
#   'F',
#   55,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'GJ16OT5388'),
#  ('2020-01-01',
#   '4:54:00',
#   'USA',
#   'F',
#   25,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'UP29QZ8801'),
#  ('2020-01-01',
#   '4:55:00',
#   'USA',
#   'F',
#   79,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'RJ10ON2838'),
#  ('2020-01-01',
#   '4:56:00',
#   'USA',
#   'M',
#   75,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'MH60YT9219'),
#  ('2020-01-01',
#   '4:57:00',
#   'India',
#   'M',
#   52,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'WB56HR5036'),
#  ('2020-01-01',
#   '4:58:00',
#   'Canada',
#   'F',
#   24,
#   'White',
#   'DUI',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'UP53QP9194'),
#  ('2020-01-01',
#   '4:59:00',
#   'USA',
#   'M',
#   21,
#   'Asian',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'RJ76OT2085'),
#  ('2020-01-01',
#   '5:00:00',
#   'USA',
#   'M',
#   59,
#   'Black',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'TN54ER6598'),
#  ('2020-01-01',
#   '5:01:00',
#   'Canada',
#   'M',
#   60,
#   'Asian',
#   'Other',
#   True,
# ...
#   '0-15 Min',
#   True,
#   'KA83IT2165'),
#  ('2020-01-01',
#   '6:40:00',
#   'India',
#   'M',
#   46,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'DL87ML4048'),
#  ('2020-01-01',
#   '6:41:00',
#   'USA',
#   'F',
#   77,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'KA43LQ7549'),
#  ('2020-01-01',
#   '6:42:00',
#   'India',
#   'F',
#   18,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'TN46AA1171'),
#  ('2020-01-01',
#   '6:43:00',
#   'USA',
#   'M',
#   63,
#   'White',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   True,
#   'RJ88QF9853'),
#  ('2020-01-01',
#   '6:44:00',
#   'India',
#   'M',
#   52,
#   'Asian',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'UP77TM9373'),
#  ('2020-01-01',
#   '6:45:00',
#   'Canada',
#   'F',
#   49,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'RJ88HZ5175'),
#  ('2020-01-01',
#   '6:46:00',
#   'Canada',
#   'M',
#   48,
#   'Asian',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'GJ12LY4426'),
#  ('2020-01-01',
#   '6:47:00',
#   'India',
#   'M',
#   26,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'WB19HX9809'),
#  ('2020-01-01',
#   '6:48:00',
#   'USA',
#   'M',
#   56,
#   'Asian',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'TN35LW1419'),
#  ('2020-01-01',
#   '6:49:00',
#   'Canada',
#   'F',
#   27,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'WB78GA7472'),
#  ('2020-01-01',
#   '6:50:00',
#   'USA',
#   'M',
#   43,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB76YZ4968'),
#  ('2020-01-01',
#   '6:51:00',
#   'USA',
#   'F',
#   78,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'RJ10EV7353'),
#  ('2020-01-01',
#   '6:52:00',
#   'Canada',
#   'M',
#   19,
#   'Black',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'TN91FD8866'),
#  ('2020-01-01',
#   '6:53:00',
#   'India',
#   'F',
#   29,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'TN36OS9491'),
#  ('2020-01-01',
#   '6:54:00',
#   'India',
#   'M',
#   52,
#   'Hispanic',
#   'Speeding',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'GJ34MZ4367'),
#  ('2020-01-01',
#   '6:55:00',
#   'Canada',
#   'M',
#   66,
#   'Asian',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'WB36AJ5454'),
#  ('2020-01-01',
#   '6:56:00',
#   'USA',
#   'F',
#   18,
#   'Other',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'DL32BU5920'),
#  ('2020-01-01',
#   '6:57:00',
#   'USA',
#   'F',
#   67,
#   'Hispanic',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'DL24OV1543'),
#  ('2020-01-01',
#   '6:58:00',
#   'Canada',
#   'F',
#   38,
#   'White',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'RJ91RX6721'),
#  ('2020-01-01',
#   '6:59:00',
#   'Canada',
#   'F',
#   31,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'MH98YY6658'),
#  ('2020-01-01',
#   '7:00:00',
#   'Canada',
#   'F',
#   43,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   False,
#   'RJ66XQ3377'),
#  ('2020-01-01',
#   '7:01:00',
#   'USA',
#   'M',
#   32,
#   'Other',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'GJ11HE3500'),
#  ('2020-01-01',
#   '7:02:00',
#   'Canada',
#   'F',
#   43,
#   'Black',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'UP37ON4423'),
#  ('2020-01-01',
#   '7:03:00',
#   'USA',
#   'F',
#   46,
#   'Other',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'WB26KV9421'),
#  ('2020-01-01',
#   '7:04:00',
#   'Canada',
#   'F',
#   54,
#   'White',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'RJ76OK1643'),
#  ('2020-01-01',
#   '7:05:00',
#   'Canada',
#   'F',
#   67,
#   'Black',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'KA69ZL3552'),
#  ('2020-01-01',
#   '7:06:00',
#   'India',
#   'M',
#   78,
#   'Other',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'RJ88XF5813'),
#  ('2020-01-01',
#   '7:07:00',
#   'India',
#   'F',
#   72,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'TN45EM9702'),
#  ('2020-01-01',
#   '7:08:00',
#   'Canada',
#   'F',
#   31,
#   'Black',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'TN93DF5332'),
#  ('2020-01-01',
#   '7:09:00',
#   'USA',
#   'F',
#   48,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'WB68DF6593'),
#  ('2020-01-01',
#   '7:10:00',
#   'USA',
#   'M',
#   22,
#   'Black',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'DL71BB3636'),
#  ('2020-01-01',
#   '7:11:00',
#   'India',
#   'M',
#   34,
#   'White',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'RJ74HO4876'),
#  ('2020-01-01',
#   '7:12:00',
#   'USA',
#   'M',
#   51,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   False,
#   'DL63XA5894'),
#  ('2020-01-01',
#   '7:13:00',
#   'India',
#   'M',
#   62,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'WB84QD8683'),
#  ('2020-01-01',
#   '7:14:00',
#   'India',
#   'F',
#   73,
#   'White',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'DL91RB4540'),
#  ('2020-01-01',
#   '7:15:00',
#   'Canada',
#   'M',
#   77,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'RJ29DN7765'),
#  ('2020-01-01',
#   '7:16:00',
#   'India',
#   'F',
#   54,
#   'Other',
#   'Speeding',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'GJ54BN4305'),
#  ('2020-01-01',
#   '7:17:00',
#   'USA',
#   'M',
#   61,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'MH76YC8522'),
#  ('2020-01-01',
#   '7:18:00',
#   'India',
#   'F',
#   50,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'DL24EC7647'),
#  ('2020-01-01',
#   '7:19:00',
#   'Canada',
#   'F',
#   24,
#   'Black',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'UP41IZ2457'),
#  ('2020-01-01',
#   '7:20:00',
#   'India',
#   'F',
#   70,
#   'Asian',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   False,
#   'GJ47DD9569'),
#  ('2020-01-01',
#   '7:21:00',
#   'USA',
#   'M',
#   39,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'DL64LX3214'),
#  ('2020-01-01',
#   '7:22:00',
#   'India',
#   'F',
#   78,
#   'Asian',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'TN44AL9653'),
#  ('2020-01-01',
#   '7:23:00',
#   'USA',
#   'F',
#   50,
#   'Black',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'WB33BY6366'),
#  ('2020-01-01',
#   '7:24:00',
#   'USA',
#   'F',
#   67,
#   'Asian',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '16-30 Min',
#   True,
#   'WB49AV3889'),
#  ('2020-01-01',
#   '7:25:00',
#   'Canada',
#   'F',
#   43,
#   'Hispanic',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '16-30 Min',
#   False,
#   'MH20DT1321'),
#  ('2020-01-01',
#   '7:26:00',
#   'India',
#   'F',
#   41,
#   'Hispanic',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'TN36AU7026'),
#  ('2020-01-01',
#   '7:27:00',
#   'USA',
#   'F',
#   34,
#   'White',
#   'Other',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   True,
#   'RJ74EU9717'),
#  ('2020-01-01',
#   '7:28:00',
#   'Canada',
#   'M',
#   44,
#   'Other',
#   'Speeding',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   False,
#   'MH52RP5371'),
#  ('2020-01-01',
#   '7:29:00',
#   'India',
#   'M',
#   71,
#   'Asian',
#   'Speeding',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'KA81XZ3904'),
#  ('2020-01-01',
#   '7:30:00',
#   'Canada',
#   'F',
#   72,
#   'Other',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'KA30YB1255'),
#  ('2020-01-01',
#   '7:31:00',
#   'India',
#   'F',
#   51,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'UP95FA4307'),
#  ('2020-01-01',
#   '7:32:00',
#   'Canada',
#   'F',
#   66,
#   'Asian',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'UP69MH4559'),
#  ('2020-01-01',
#   '7:33:00',
#   'USA',
#   'M',
#   23,
#   'White',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   False,
#   'MH36LB8110'),
#  ('2020-01-01',
#   '7:34:00',
#   'USA',
#   'F',
#   43,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'DL44IU1255'),
#  ('2020-01-01',
#   '7:35:00',
#   'USA',
#   'F',
#   53,
#   'Hispanic',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'TN98ST2956'),
#  ('2020-01-01',
#   '7:36:00',
#   'Canada',
#   'F',
#   75,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'KA64ZE9015'),
#  ('2020-01-01',
#   '7:37:00',
#   'India',
#   'M',
#   42,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'TN31LI5051'),
#  ('2020-01-01',
#   '7:38:00',
#   'India',
#   'M',
#   71,
#   'Other',
#   'Other',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'KA84TJ1967'),
#  ('2020-01-01',
#   '7:39:00',
#   'USA',
#   'M',
#   18,
#   'White',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   False,
#   'MH54DI8436'),
#  ('2020-01-01',
#   '7:40:00',
#   'USA',
#   'F',
#   21,
#   'Asian',
#   'Speeding',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '30+ Min',
#   True,
#   'DL60ZU8041'),
#  ('2020-01-01',
#   '7:41:00',
#   'USA',
#   'F',
#   61,
#   'Black',
#   'DUI',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '30+ Min',
#   False,
#   'DL67MJ4900'),
#  ('2020-01-01',
#   '7:42:00',
#   'Canada',
#   'M',
#   73,
#   'Black',
#   'Other',
#   True,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   True,
#   'RJ79EO5783'),
#  ('2020-01-01',
#   '7:43:00',
#   'Canada',
#   'M',
#   41,
#   'Asian',
#   'Other',
#   False,
#   'Frisk',
#   'Warning',
#   False,
#   '30+ Min',
#   True,
#   'RJ64MO5092'),
#  ('2020-01-01',
#   '7:44:00',
#   'USA',
#   'M',
#   23,
#   'Asian',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '0-15 Min',
#   True,
#   'GJ15JU3857'),
#  ('2020-01-01',
#   '7:45:00',
#   'USA',
#   'F',
#   74,
#   'Asian',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'RJ16ZV3710'),
#  ('2020-01-01',
#   '7:46:00',
#   'India',
#   'F',
#   18,
#   'White',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   False,
#   'WB50IL2063'),
#  ('2020-01-01',
#   '7:47:00',
#   'India',
#   'M',
#   67,
#   'Hispanic',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   True,
#   '30+ Min',
#   False,
#   'GJ10AV4572'),
#  ('2020-01-01',
#   '7:48:00',
#   'Canada',
#   'M',
#   24,
#   'White',
#   'Speeding',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'KA31TR8661'),
#  ('2020-01-01',
#   '7:49:00',
#   'Canada',
#   'M',
#   63,
#   'Black',
#   'Signal',
#   True,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'MH39MI7719'),
#  ('2020-01-01',
#   '7:50:00',
#   'USA',
#   'F',
#   25,
#   'Hispanic',
#   'Other',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'KA50QA2878'),
#  ('2020-01-01',
#   '7:51:00',
#   'India',
#   'F',
#   79,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'MH35VM4667'),
#  ('2020-01-01',
#   '7:52:00',
#   'USA',
#   'M',
#   23,
#   'Hispanic',
#   'DUI',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'WB73DI9560'),
#  ('2020-01-01',
#   '7:53:00',
#   'Canada',
#   'M',
#   77,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '16-30 Min',
#   False,
#   'MH90QR4300'),
#  ('2020-01-01',
#   '7:54:00',
#   'USA',
#   'F',
#   28,
#   'Other',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'RJ79TH3094'),
#  ('2020-01-01',
#   '7:55:00',
#   'India',
#   'M',
#   59,
#   'Other',
#   'Other',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'GJ78GB1264'),
#  ('2020-01-01',
#   '7:56:00',
#   'Canada',
#   'F',
#   31,
#   'Asian',
#   'Seatbelt',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '16-30 Min',
#   True,
#   'TN77JY6996'),
#  ('2020-01-01',
#   '7:57:00',
#   'Canada',
#   'F',
#   52,
#   'Black',
#   'Signal',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   False,
#   'WB50NK8310'),
#  ('2020-01-01',
#   '7:58:00',
#   'USA',
#   'M',
#   75,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'GJ72QJ5705'),
#  ('2020-01-01',
#   '7:59:00',
#   'India',
#   'M',
#   27,
#   'Hispanic',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'UP67JJ9719'),
#  ('2020-01-01',
#   '8:00:00',
#   'USA',
#   'M',
#   32,
#   'Black',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'TN31IM1925'),
#  ('2020-01-01',
#   '8:01:00',
#   'Canada',
#   'F',
#   62,
#   'White',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'MH89KZ1130'),
#  ('2020-01-01',
#   '8:02:00',
#   'Canada',
#   'F',
#   28,
#   'Hispanic',
#   'Signal',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'MH74WR7730'),
#  ('2020-01-01',
#   '8:03:00',
#   'Canada',
#   'M',
#   57,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '16-30 Min',
#   True,
#   'MH57GF6888'),
#  ('2020-01-01',
#   '8:04:00',
#   'Canada',
#   'F',
#   57,
#   'Hispanic',
#   'Seatbelt',
#   True,
#   'Frisk',
#   'Arrest',
#   True,
#   '16-30 Min',
#   True,
#   'KA97OO1052'),
#  ('2020-01-01',
#   '8:05:00',
#   'USA',
#   'M',
#   55,
#   'Black',
#   'DUI',
#   True,
#   'Frisk',
#   'Warning',
#   True,
#   '30+ Min',
#   True,
#   'MH38PE1728'),
#  ('2020-01-01',
#   '8:06:00',
#   'USA',
#   'M',
#   46,
#   'Hispanic',
#   'DUI',
#   False,
#   'Frisk',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'KA60JY9350'),
#  ('2020-01-01',
#   '8:07:00',
#   'India',
#   'F',
#   45,
#   'Black',
#   'Seatbelt',
#   False,
#   'Frisk',
#   'Ticket',
#   True,
#   '0-15 Min',
#   False,
#   'MH24QM6143'),
#  ('2020-01-01',
#   '8:08:00',
#   'Canada',
#   'M',
#   28,
#   'Black',
#   'Speeding',
#   False,
#   'Vehicle Search',
#   'Ticket',
#   False,
#   '0-15 Min',
#   True,
#   'GJ86KG8254'),
#  ('2020-01-01',
#   '8:09:00',
#   'India',
#   'F',
#   73,
#   'Asian',
#   'Signal',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'DL38RH9723'),
#  ('2020-01-01',
#   '8:10:00',
#   'USA',
#   'M',
#   71,
#   'Hispanic',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   True,
#   '16-30 Min',
#   True,
#   'KA33IQ4745'),
#  ('2020-01-01',
#   '8:11:00',
#   'Canada',
#   'F',
#   79,
#   'Black',
#   'Seatbelt',
#   True,
#   'Vehicle Search',
#   'Arrest',
#   True,
#   '0-15 Min',
#   True,
#   'KA76II3670'),
#  ('2020-01-01',
#   '8:12:00',
#   'India',
#   'F',
#   44,
#   'Asian',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '0-15 Min',
#   False,
#   'WB64WF4182'),
#  ('2020-01-01',
#   '8:13:00',
#   'USA',
#   'F',
#   33,
#   'Other',
#   'DUI',
#   False,
#   'Frisk',
#   'Arrest',
#   False,
#   '0-15 Min',
#   True,
#   'MH83IH9497'),
#  ('2020-01-01',
#   '8:14:00',
#   'USA',
#   'M',
#   29,
#   'Other',
#   'Signal',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'DL82ZO1778'),
#  ('2020-01-01',
#   '8:15:00',
#   'USA',
#   'M',
#   67,
#   'Black',
#   'Signal',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '0-15 Min',
#   False,
#   'DL37CK3012'),
#  ('2020-01-01',
#   '8:16:00',
#   'Canada',
#   'M',
#   75,
#   'Asian',
#   'Other',
#   True,
#   'Vehicle Search',
#   'Warning',
#   False,
#   '16-30 Min',
#   True,
#   'KA76OG9154'),
#  ('2020-01-01',
#   '8:17:00',
#   'USA',
#   'M',
#   75,
#   'Hispanic',
#   'Speeding',
#   True,
#   'Frisk',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'TN10OV8122'),
#  ('2020-01-01',
#   '8:18:00',
#   'Canada',
#   'M',
#   32,
#   'Hispanic',
#   'Other',
#   False,
#   'Vehicle Search',
#   'Arrest',
#   False,
#   '30+ Min',
#   False,
#   'DL91QW3561'),
#  ('2020-01-01',
#   '8:19:00',
#   'USA',
#   'M',
#   63,
#   'Other',
#   'Signal',
#   False,
#   'Frisk',
#   'Arrest',
#   True,
#   '30+ Min',
#   True,
#   'KA94DL5663')]

# %% [markdown]
# 5. Database Connection

# %%
connection = db.connect(
    host = "localhost",
    user = "root",
    password = "sandy2505",
    database = "db1"
)
curr = connection.cursor()

# %%
q = """
create table digital_logs
(
    stop_date DATE,
    stop_time TIME,                
    country_name VARCHAR(50),         
    driver_gender VARCHAR(10),
    driver_age INT,
    driver_race VARCHAR(50),
    violation VARCHAR(100),
    search_conducted VARCHAR(50),
    search_type VARCHAR(50),
    stop_outcome VARCHAR(50),
    is_arrested  VARCHAR(20),
    stop_duration VARCHAR(50),
    drugs_related_stop VARCHAR(50),
    vehicle_number VARCHAR(50) 
 )
"""
curr.execute(q)

# %%
insert = """
insert into digital_logs
values
(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
"""

curr.executemany(insert,val)
connection.commit()
